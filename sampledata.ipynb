# %%
from scipy.io import whosmat

# Get information about variables in the MATLAB file
variables_info = whosmat("/Users/ritikraut/Desktop/D08/BaselineOnline230416T094733.mat")

# Print information about each variable
for var_info in variables_info:
    print(f"Variable name: {var_info[0]}, Shape: {var_info[1]}, Data type: {var_info[2]}")
# Out:
# Variable name: baseActivity, Shape: (24, 53554), Data type: double

# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt

# Load specific variable from the MATLAB file
mat_data = loadmat("/Users/ritikraut/Desktop/D08/BaselineOnline230416T094733.mat")
variable_name = "baseActivity"  # Replace with the actual variable name
variable_data = mat_data[variable_name]

# Check the shape and data type of the loaded variable
print("Shape:", variable_data.shape)
print("Data type:", variable_data.dtype)

# Plot the data from the loaded variable
plt.plot(variable_data[0])  # Plot the first row of data (assuming it represents time series)
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Base Activity Data')
plt.show()
# Out:
# Shape: (24, 53554)
# Data type: float64

# %%
from scipy.io import whosmat

# Get information about variables in the MATLAB file
variables_info = whosmat("/Users/ritikraut/Desktop/D08/BaselineOnline230416T094733.mat")

# Print information about each variable
for var_info in variables_info:
    print(f"Variable name: {var_info[0]}, Shape: {var_info[1]}, Data type: {var_info[2]}")
# Out:
# Variable name: baseActivity, Shape: (24, 53554), Data type: double

# %%
# Get information about variables in the MATLAB file
variables_info = whosmat("/Users/ritikraut/Desktop/D08/roi_data.mat")

# Print information about each variable
for var_info in variables_info:
    print(f"Variable name: {var_info[0]}, Shape: {var_info[1]}, Data type: {var_info[2]}")
# Out:
# Variable name: im_sc_struct, Shape: (1, 1), Data type: struct
# Variable name: plot_images, Shape: (1, 2), Data type: struct
# Variable name: roi_data, Shape: (1, 1), Data type: struct

# %%
# Get information about variables in the MATLAB file
variables_info = whosmat("/Users/ritikraut/Desktop/D08/BMI_online230416T103652.mat")

# Print information about each variable
for var_info in variables_info:
    print(f"Variable name: {var_info[0]}, Shape: {var_info[1]}, Data type: {var_info[2]}")
# Out:
# Variable name: bData, Shape: (1, 1), Data type: struct
# Variable name: data, Shape: (1, 1), Data type: struct

# %%
# Get information about variables in the MATLAB file
variables_info = whosmat("/Users/ritikraut/Desktop/D08/BMI_target_info_20230416T100533.mat")

# Print information about each variable
for var_info in variables_info:
    print(f"Variable name: {var_info[0]}, Shape: {var_info[1]}, Data type: {var_info[2]}")
# Out:
# Variable name: E1_base, Shape: (1, 2), Data type: double
# Variable name: E2_base, Shape: (1, 2), Data type: double
# Variable name: E_id, Shape: (4, 1), Data type: double
# Variable name: E1_sel_idxs, Shape: (2, 1), Data type: double
# Variable name: E2_sel_idxs, Shape: (2, 1), Data type: double
# Variable name: decoder, Shape: (4, 1), Data type: double
# Variable name: n_mean, Shape: (1, 4), Data type: double
# Variable name: n_std, Shape: (1, 4), Data type: double
# Variable name: E1_std, Shape: (1, 1), Data type: double
# Variable name: E2_subord_mean, Shape: (2, 1), Data type: double
# Variable name: E2_subord_std, Shape: (2, 1), Data type: double
# Variable name: E2_coeff, Shape: (1, 1), Data type: double
# Variable name: E2_subord_thresh, Shape: (2, 1), Data type: double
# Variable name: E1_coeff, Shape: (1, 1), Data type: double
# Variable name: E1_thresh, Shape: (1, 1), Data type: double
# Variable name: T1, Shape: (1, 1), Data type: double

# %%
# Get information about variables in the MATLAB file
variables_info = whosmat("/Users/ritikraut/Desktop/D08/strcMask.mat")

# Print information about each variable
for var_info in variables_info:
    print(f"Variable name: {var_info[0]}, Shape: {var_info[1]}, Data type: {var_info[2]}")
# Out:
# Variable name: E_id, Shape: (4, 1), Data type: double
# Variable name: E_base_sel, Shape: (1, 4), Data type: double
# Variable name: strcMask, Shape: (1, 1), Data type: struct

# %%
# Get information about variables in the MATLAB file
variables_info = whosmat("/Users/ritikraut/Desktop/D08/target_calibration_ALL_20230416T100533.mat")

# Print information about each variable
for var_info in variables_info:
    print(f"Variable name: {var_info[0]}, Shape: {var_info[1]}, Data type: {var_info[2]}")
# Out:
# Variable name: n_f_file, Shape: (1,), Data type: char
# Variable name: roi_data_file, Shape: (1,), Data type: char
# Variable name: E1_base, Shape: (1, 2), Data type: double
# Variable name: E2_base, Shape: (1, 2), Data type: double
# Variable name: frames_per_reward_range, Shape: (1, 2), Data type: double
# Variable name: tset, Shape: (1, 1), Data type: struct
# Variable name: savePath, Shape: (1,), Data type: char
# Variable name: fbset, Shape: (1, 1), Data type: struct
# Variable name: target_cal_ALL_path, Shape: (1,), Data type: char
# Variable name: fb_cal, Shape: (1, 1), Data type: struct
# Variable name: plot_b, Shape: (1, 3), Data type: double
# Variable name: plot_o, Shape: (1, 3), Data type: double
# Variable name: E_color, Shape: (1, 2), Data type: cell
# Variable name: plot_raw_bool, Shape: (1, 1), Data type: double
# Variable name: plot_f0_bool, Shape: (1, 1), Data type: double
# Variable name: plot_smooth_bool, Shape: (1, 1), Data type: double
# ...

# %%
from scipy.io import loadmat

# Load the MATLAB file
mat_data = loadmat("/Users/ritikraut/Desktop/D08/target_calibration_ALL_20230416T100533.mat")

# Get the variable you are interested in (e.g., 'my_variable')
my_variable= mat_data['baseActivity']

# Print detailed information about the variable
print(f"Variable name: my_variable")
print(f"Shape: {my_variable.shape}")
print(f"Data type: {my_variable.dtype}")
print(f"Minimum value: {my_variable.min()}")
print(f"Maximum value: {my_variable.max()}")
# Out:
# Variable name: my_variable
# Shape: (24, 53554)
# Data type: float64
# Minimum value: nan
# Maximum value: nan

# %%
import pandas as pd

Experimental_design = {}
Data_acquisition = {}
Neural_activity = {}
Experimental_subjects = {}
Behavior = {}

# Experimental design
Experimental_design['Stimuli'] = ['roi_data', 'frames_per_reward_range', 'E_color']
Experimental_design['Environment'] = ['plotPath', 'im_path', 'savepath']
Experimental_design['Trial_structure'] = ['TO', 'T', 'T_min', 'T_delta', 'T_vec']
Experimental_design['Optogenetics'] = ['']

# Data acquisition
Data_acquisition['Device settings'] = ['num_neurons', 'num_samples', 'num_E1', 'num_E2', 'num_fb_bins']
Data_acquisition['Filtering parameters'] = ['', '']
Data_acquisition['Sampling rate'] = ['']
Data_acquisition['Recording/imaging area'] = ['E1_temp', 'E2_temp', 'E1_raw', 'E2_raw', 'f', 'f_base', 'f_raw']

# Neural Activity
Neural_activity['Extracellular electrophysiology'] = ['baseActivity', 'E1_proj', 'E2_proj', 'E1_norm', 'E2_norm', 'valid_idxs', 'E_id', 'E1_sel', 'E1_sel_idxs', 'E2_sel', 'E2_sel_idxs', 'E_base_sel', 'decoder', 'indn', 'var_i', 'E2_i', 'E2_coeff0', 'E2_coeff', 'E2_coeff_min', 'E2_subord_thresh', 'E2_coeff_delta', 'E2_coeff_vec', 'E2_subord_mean', 'E2_subord_std', 'E2_subord_mean_analyze', 'E2_dom_samples', 'E2_dom_sel', 'E2_coeff_vec']
Neural_activity['Intracellular electrophysiology'] = ['']  
Neural_activity['Two-photon imaging'] = ['EnsembleMask', 'auxmask', 'strcMask']

# Experimental Subjects
Experimental_subjects['Species'] = ['']
Experimental_subjects['Genotype'] = ['']
Experimental_subjects['Age'] = ['']
Experimental_subjects['Weight'] = ['']

# Behavior
Behavior['Task accuracy'] = ['']
Behavior['Task response time'] = ['']
Behavior['Video and motion tracking'] = ['']
Behavior['Audio'] = ['']

experimental_design_df = pd.DataFrame(Experimental_design.items(), columns=["Category", "Variables"])
data_acquisition_df = pd.DataFrame(Data_acquisition.items(), columns=["Category", "Variables"])
neural_activity_df = pd.DataFrame(Neural_activity.items(), columns=["Category", "Variables"])
experimental_subjects_df = pd.DataFrame(Experimental_subjects.items(), columns=["Category", "Variables"])
behavior_df = pd.DataFrame(Behavior.items(), columns=["Category", "Variables"])


print("\nExpermental Design:")
print(experimental_design_df)
print("\nData Acquisition:")
print(data_acquisition_df)
# Out:
# Expermental Design:
#           Category                                     Variables
# 0          Stimuli  [roi_data, frames_per_reward_range, E_color]
# 1      Environment                 [plotPath, im_path, savepath]
# 2  Trial_structure                [TO, T, T_min, T_delta, T_vec]
# 3     Optogenetics                                            []
#
# Data Acquisition:
#                  Category                                          Variables
# 0         Device settings  [num_neurons, num_samples, num_E1, num_E2, num...
# 1    Filtering parameters                     [filter_param1, filter_param2]
# 2           Sampling rate                                    [sampling_rate]
# 3  Recording/imaging area  [E1_temp, E2_temp, E1_raw, E2_raw, f, f_base, ...
